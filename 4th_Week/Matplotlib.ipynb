# %% [markdown]
# ##**Matplotlib**

# %%
import matplotlib.pyplot as plt

X = range(100)
Y = [value**2 for value in X]
plt.plot(X,Y)
plt.show()

# %%
import numpy as np

X_1 = range(100)
Y_1 = [np.cos(value) for value in X]

X_2 = range(100)
Y_2 = [np.sin(value) for value in X]

plt.plot(X_1, Y_1)
plt.plot(X_2, Y_2)

# %%
fig = plt.figure()    # figure 반환
fig.set_size_inches(10,5)    # 크기지정
ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)

ax_1.plot(X_1, Y_1, c='b')
ax_2.plot(X_2, Y_2, c='g')
plt.show()

# %%
X_1 = range(100)
X_2 = range(100)

Y_1 = [value + 100 for value in X]
Y_2 = [value for value in Y]

# %% [markdown]
# #####Set color

# %%
plt.plot(X_1, Y_1, color="#eeefff")
plt.plot(X_2, Y_2, color="r")

plt.show()

# %% [markdown]
# #####Set linestyle

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")
plt.plot(X_2, Y_2, c="r", ls="dotted")

plt.show()

# %% [markdown]
# #####Set title

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")
plt.plot(X_2, Y_2, c="r", ls="dotted")

plt.title("Two lines")
plt.show()

# %%
plt.plot(X_1, Y_1, c="b", linestyle="dashed")
plt.plot(X_2, Y_2, c="r", ls="dotted")

plt.title('$y = \\frac{ax+b}{test}$')
plt.show()

# %%
plt.plot(X_1, Y_1, color="b", linestyle="dashed", label='line_1')
plt.plot(X_2, Y_2, color="r", linestyle="dotted", label='line_2')

plt.legend(shadow=True, fancybox=True, loc="lower right")

# %% [markdown]
# #####Set grid & xylim

# %%
plt.grid(True, lw=0.4, ls="--", c=".90")

plt.xlim(-100, 200)
plt.ylim(-100, 200)
# Out:
# (-100.0, 200.0)

# %% [markdown]
# ##**Matplotlib Graph**

# %% [markdown]
# #####scatter

# %%
data_1 = np.random.rand(512, 2)
data_2 = np.random.rand(512, 2)

plt.scatter(data_1[:,0],data_1[:,1],c="b", marker="x")
plt.scatter(data_2[:,0],data_1[:,1],c="r", marker="^")

plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# #####Bar chart

# %%
data = [[5.,25.,50.,20.],
        [4.,23.,51.,17],
        [6.,22.,52.,19]]

X = np.arange(4)
plt.bar(X + 0.00, data[0], color = 'b', width = 0.25)
plt.bar(X + 0.25, data[1], color = 'g', width = 0.25)
plt.bar(X + 0.50, data[2], color = 'r', width = 0.25)
plt.xticks(X+0.25,("A","B","C","D"))
plt.show()

# %%
data = np.array([[5., 25., 50., 20.],
        [4., 23., 51., 17],
        [6., 22., 52., 19]])

color_list = ['b','g','r']
data_label = ["A","B","C"]
X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(X, data[i], bottom = np.sum(data[:i], axis=0),
            color = color_list[i], label=data_label[i])
plt.legend()
plt.show()

# %% [markdown]
# #####histogram

# %%
X = np.random.randn(1000)
plt.hist(X, bins=100)
plt.show()

# %%
data = np.random.randn(100,5)
plt.boxplot(data)

plt.show()

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_data = pd.read_csv("/content/gdrive/MyDrive/Study/Boostcourse/인공지능(AI) 기초 다지기 [22.01.13 ~ 22.02.24]/4th_Week/Reference/HousingData.csv")
df_data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
#
# [5 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
ax = []

fig = plt.figure()

for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))
ax[0].scatter(df_data["CRIM"],df_data["MEDV"])
ax[1].scatter(df_data["PTRATIO"],df_data["MEDV"])
ax[2].scatter(df_data["AGE"],df_data["MEDV"])
ax[3].scatter(df_data["NOX"],df_data["MEDV"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ax = []

fig = plt.figure()

for i in range(1,5):
    ax.append(fig.add_subplot(2,2,i))
ax[0].scatter(df_data["CRIM"],df_data["MEDV"], color="b", label="CRIM")
ax[1].scatter(df_data["PTRATIO"],df_data["MEDV"], color="g")
ax[2].scatter(df_data["AGE"],df_data["MEDV"])
ax[3].scatter(df_data["NOX"],df_data["MEDV"])
plt.subplots_adjust(wspace=0, hspace=0)
ax[0].legend()
ax[0].set_title("CRIM")
plt.show()

# %%
df_data.plot()

# %%
fig = plt.figure()
fig.set_size_inches(10,5)
ax_1 = fig.add_subplot(1,2,1)
ax_2 = fig.add_subplot(1,2,2)
ax_1.plot(df_data["MEDV"])
ax_2.hist(df_data["MEDV"], bins=50)
ax_1.set_title("House prcie MEDV")
ax_2.set_title("House prcie MEDV")
# Out:
# Text(0.5, 1.0, 'House prcie MEDV')

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
scale_data = std_scaler.fit_transform(df_data)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.boxplot(scale_data, labels=df_data.columns)
fig.set_size_inches(18.5, 10.5)

# %%
import pandas
from pandas.plotting import scatter_matrix

pandas.plotting.scatter_matrix(df_data, diagonal="kde", alpha=1, figsize=(20,20))
plt.show()

# %%
corr_data = np.corrcoef(scale_data.T)
'''
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr_data, vmin=-1, vmax=1, interpolation='nearest')
fig.colorbar(cax)
fig.set_size_inches(10,10)
ticks=np.arange(0,14,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.set_xticklabels(df_data.columns)
ax.set_yticklabels(df_data.columns)
'''

fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
cax = ax.matshow(corr_data, vmin=-1, vmax=1, interpolation='nearest')
fig.colorbar(cax)
ticks=np.arange(0,corr_data.shape[0],1)

ax.set_xticks(ticks)
ax.set_yticks(ticks) 
ax.set_xticklabels(df_data.columns)
ax.set_yticklabels(df_data.columns)
# Out:
# [Text(0, 0, 'CRIM'),
#  Text(0, 0, 'ZN'),
#  Text(0, 0, 'INDUS'),
#  Text(0, 0, 'CHAS'),
#  Text(0, 0, 'NOX'),
#  Text(0, 0, 'RM'),
#  Text(0, 0, 'AGE'),
#  Text(0, 0, 'DIS'),
#  Text(0, 0, 'RAD'),
#  Text(0, 0, 'TAX'),
#  Text(0, 0, 'PTRATIO'),
#  Text(0, 0, 'B'),
#  Text(0, 0, 'LSTAT'),
#  Text(0, 0, 'MEDV')]
